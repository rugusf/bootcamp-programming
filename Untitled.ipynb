# %%
import pandas as pd

# %%
df = pd.read_table("bootcamp/data/experiment_data.txt", index_col=0)

# %%
df
# Out:
#                0        1        2        3     4        5     6        7  \
# YAL001C  0.68000 -0.02000 -0.10000  0.84000  0.06 -1.80000  0.18  0.58000
# YAL002W -0.62000 -0.75000 -0.08000  0.23000 -0.30  0.22000 -0.04  0.23000
# YAL003W -0.30000  0.70000  0.86000  0.93000 -0.25  0.86000 -0.84 -0.25000
# YAL005C -0.04000  0.37000 -0.86000  0.90000 -0.97 -0.14000 -1.36  0.20731
# YAL007C  0.49000  0.01000  0.33000  0.10000 -0.22  0.19000 -0.38 -0.29000
# YAL008W -0.07000  0.04000 -0.15000  0.41000 -0.42  0.21000 -0.01  0.69000
# YAL009W -0.27000 -0.68000  0.21000  0.11000  0.02 -0.04000 -0.13  0.18000
# YAL010C  0.20000  0.19000  0.44000  0.43000 -0.14  0.14000  0.18  0.33000
# YAL011W -0.09000  0.25000  0.04000  0.51000 -0.04  0.30000  0.20  0.00000
# YAL012W -0.03000  0.84000  0.44000  0.77000  0.04 -0.06000  0.32  0.18000
# YAL014C -0.06000  0.19000  0.15000  0.28000 -0.58  0.60000 -0.45  0.28000
# YAL015C  0.08000 -0.20000 -0.45000 -0.06000 -0.14 -0.92000  0.01  0.77000
# ...
